# %% [markdown]
# # Face Recovery GAN — Colab Training
#
# Two-stage face recovery: pose correction + de-occlusion.
# Train on T4 GPU (~3-5 hours for 80 epochs on 20K CelebA)

# %%
# Cell 1: Install dependencies
# !pip install torch torchvision opencv-python numpy tqdm pyyaml tensorboard scikit-image facenet-pytorch scipy albumentations gdown

# %%
# Cell 2: Clone project
import os
if not os.path.exists('biometric-ai'):
    # !git clone <YOUR_REPO_URL>
# %cd biometric-ai

# %%
# Cell 3: Download CelebA subset
# Try Google Drive first (may hit quota)
# !python download_celebA.py --root ./data/celebA --subset 20000

# Fallback: Kaggle (no API key needed)
# !python download_celebA.py --source kaggle --root ./data/celebA --subset 20000
# !python download_masks.py --root ./data/masks

# %%
# Cell 4: Verify GPU
import torch
print(f"CUDA: {torch.cuda.is_available()}, Device: {torch.cuda.get_device_name(0)}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f}GB")

# %%
# Cell 5: Start TensorBoard
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# Cell 6: Train
# !python train.py --config configs/config.yaml

# %%
# Cell 7: Download checkpoint
from google.colab import files
files.download('./checkpoints/final.pt')
